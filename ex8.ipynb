# %%
# !pip install diffusers
# Out:
# Collecting diffusers
#   Downloading diffusers-0.39.0-py3-none-any.whl.metadata (20 kB)
# Collecting importlib_metadata (from diffusers)
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: filelock in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (3.29.4)
# Requirement already satisfied: httpx<1.0.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (0.36.2)
# Requirement already satisfied: numpy in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2.2.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2026.5.9)
# Requirement already satisfied: requests in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2.32.4)
# Requirement already satisfied: safetensors>=0.8.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (0.8.0)
# Requirement already satisfied: Pillow in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (11.3.0)
# Requirement already satisfied: anyio in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (2026.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.14.1)
# Requirement already satisfied: colorama in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.34.0->diffusers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1.0.0->diffusers) (1.3.1)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers)
#   Downloading zipp-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (2.5.0)
# Downloading diffusers-0.39.0-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.6 MB 6.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.6 MB 7.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.0/5.6 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 7.4 MB/s  0:00:00
# Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Downloading zipp-4.1.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, importlib_metadata, diffusers
#
#    ---------------------------------------- 0/3 [zipp]
#    ------------- -------------------------- 1/3 [importlib_metadata]
#    ------------- -------------------------- 1/3 [importlib_metadata]
#    ------------- -------------------------- 1/3 [importlib_metadata]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    -------------------------- ------------- 2/3 [diffusers]
#    ---------------------------------------- 3/3 [diffusers]
#
# Successfully installed diffusers-0.39.0 importlib_metadata-9.0.0 zipp-4.1.0
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float32
)

pipe = pipe.to("cpu")

image = pipe(
    "A futuristic city skyline at sunset",
    num_inference_steps=30
).images[0]

image.save("generated_city.png")
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-1.14.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (2.12.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (0.8.0)
# Requirement already satisfied: filelock in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2026.6.0)
# Requirement already satisfied: requests in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.14.1)
# Requirement already satisfied: setuptools<82 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.8.3)
# Downloading accelerate-1.14.0-py3-none-any.whl (389 kB)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.14.0
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float32
)

pipe = pipe.to("cpu")

image = pipe(
    "A futuristic city skyline at sunset",
    num_inference_steps=30
).images[0]

image.save("generated_city.png")
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
