# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
from transformers import pipeline

# 1. Knowledge base
documents = [
    "The Eiffel Tower is located in Paris, France and was completed in 1889.",
    "Retrieval-Augmented Generation combines document retrieval with text generation.",
    "Python is a popular high-level programming language used in AI development.",
    "Vector databases store embeddings and support fast similarity search."
]

# 2. Embed documents
embed_model = SentenceTransformer("all-MiniLM-L6-v2")
doc_embeddings = embed_model.encode(documents)

# 3. Build FAISS index
dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(doc_embeddings, dtype=np.float32))

# 4. Query and retrieve top-2 relevant chunks
query = "What is RAG in AI?"
query_embedding = embed_model.encode([query])

D, I = index.search(np.array(query_embedding, dtype=np.float32), k=2)
retrieved_chunks = [documents[i] for i in I[0]]

# 5. Build augmented prompt and generate answer
context = " ".join(retrieved_chunks)
prompt = f"Context: {context}\nQuestion: {query}\nAnswer:"

generator = pipeline("text2text-generation", model="google/flan-t5-base")
answer = generator(prompt, max_length=60)

print("Retrieved Context:")
print(retrieved_chunks)

print("\nAnswer:")
print(answer[0]["generated_text"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 import faiss
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-5.6.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (4.56.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (0.36.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (2.12.1)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (2.2.6)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (1.16.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (4.14.1)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: filelock in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (3.29.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (2026.5.9)
# Requirement already satisfied: requests in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (0.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (2026.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.22.0->sentence_transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.22.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.0.0->sentence_transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence_transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence_transformers) (2025.8.3)
# Downloading sentence_transformers-5.6.1-py3-none-any.whl (596 kB)
#    ---------------------------------------- 0.0/596.7 kB ? eta -:--:--
#    ---------------------------------------- 596.7/596.7 kB 6.6 MB/s  0:00:00
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-5.6.1
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
from transformers import pipeline

# 1. Knowledge base
documents = [
    "The Eiffel Tower is located in Paris, France and was completed in 1889.",
    "Retrieval-Augmented Generation combines document retrieval with text generation.",
    "Python is a popular high-level programming language used in AI development.",
    "Vector databases store embeddings and support fast similarity search."
]

# 2. Embed documents
embed_model = SentenceTransformer("all-MiniLM-L6-v2")
doc_embeddings = embed_model.encode(documents)

# 3. Build FAISS index
dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(doc_embeddings, dtype=np.float32))

# 4. Query and retrieve top-2 relevant chunks
query = "What is RAG in AI?"
query_embedding = embed_model.encode([query])

D, I = index.search(np.array(query_embedding, dtype=np.float32), k=2)
retrieved_chunks = [documents[i] for i in I[0]]

# 5. Build augmented prompt and generate answer
context = " ".join(retrieved_chunks)
prompt = f"Context: {context}\nQuestion: {query}\nAnswer:"

generator = pipeline("text2text-generation", model="google/flan-t5-base")
answer = generator(prompt, max_length=60)

print("Retrieved Context:")
print(retrieved_chunks)

print("\nAnswer:")
print(answer[0]["generated_text"])
# Out:
# WARNING:tensorflow:From C:\Users\Janani\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from sentence_transformers import SentenceTransformer
# ----> 2 import faiss
#       3 import numpy as np
#       4 from transformers import pipeline
#
# ModuleNotFoundError: No module named 'faiss'

# %%
# !pip install faiss
# Out:
# ERROR: Could not find a version that satisfies the requirement faiss (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for faiss

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.15.0-cp313-cp313-win_amd64.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.25 in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from faiss-cpu) (2.2.6)
# Requirement already satisfied: packaging in c:\users\janani\appdata\local\programs\python\python313\lib\site-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.15.0-cp313-cp313-win_amd64.whl (16.3 MB)
#    ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/16.3 MB 7.9 MB/s eta 0:00:02
#    --------- ------------------------------ 3.7/16.3 MB 9.7 MB/s eta 0:00:02
#    -------------- ------------------------- 5.8/16.3 MB 9.6 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.3 MB 10.2 MB/s eta 0:00:01
#    ------------------------- -------------- 10.5/16.3 MB 10.5 MB/s eta 0:00:01
#    -------------------------------- ------- 13.1/16.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.3 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 16.3/16.3 MB 11.0 MB/s  0:00:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.15.0
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
from transformers import pipeline

# 1. Knowledge base
documents = [
    "The Eiffel Tower is located in Paris, France and was completed in 1889.",
    "Retrieval-Augmented Generation combines document retrieval with text generation.",
    "Python is a popular high-level programming language used in AI development.",
    "Vector databases store embeddings and support fast similarity search."
]

# 2. Embed documents
embed_model = SentenceTransformer("all-MiniLM-L6-v2")
doc_embeddings = embed_model.encode(documents)

# 3. Build FAISS index
dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(doc_embeddings, dtype=np.float32))

# 4. Query and retrieve top-2 relevant chunks
query = "What is RAG in AI?"
query_embedding = embed_model.encode([query])

D, I = index.search(np.array(query_embedding, dtype=np.float32), k=2)
retrieved_chunks = [documents[i] for i in I[0]]

# 5. Build augmented prompt and generate answer
context = " ".join(retrieved_chunks)
prompt = f"Context: {context}\nQuestion: {query}\nAnswer:"

generator = pipeline("text2text-generation", model="google/flan-t5-base")
answer = generator(prompt, max_length=60)

print("Retrieved Context:")
print(retrieved_chunks)

print("\nAnswer:")
print(answer[0]["generated_text"])
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\Janani\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Janani\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# C:\Users\Janani\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Janani\.cache\huggingface\hub\models--google--flan-t5-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
